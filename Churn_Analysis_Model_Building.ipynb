# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import sklearn
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imblearn.combine import SMOTEENN

# %%
print(sklearn.__version__)
# Out:
# 1.2.2

# %% [markdown]
# #### Reading csv

# %%
df=pd.read_csv("tel_churn.csv")
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0           True        False       False         True           True  ...
# 1          False         True        True        False           True  ...
# 2          False         True        True        False           True  ...
# 3          False         True        True        False           True  ...
# 4           True        False        True        False           True  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                     True
# 4                                    False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                  False                           False
# 4                                  False                            True
#
#    PaymentMethod_Mailed check  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0                       False                 True                 False
# 1                        True                False                 False
# 2                        True                 True                 False
# 3                       False                False                 False
# 4                       False                 True                 False
#
#    tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                 False                 False                 False
# 1                  True                 False                 False
# 2                 False                 False                 False
# 3                 False                  True                 False
# 4                 False                 False                 False
#
#    tenure_group_61 - 72
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 52 columns]

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
x=df.drop('Churn',axis=1)
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85           True        False
# 1                 0           56.95       1889.50          False         True
# 2                 0           53.85        108.15          False         True
# 3                 0           42.30       1840.75          False         True
# 4                 0           70.70        151.65           True        False
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50          False         True
# 7028              0          103.20       7362.90           True        False
# 7029              0           29.60        346.45           True        False
# 7030              1           74.40        306.60          False         True
# 7031              0          105.65       6844.50          False         True
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# 0          False         True           True           False             True
# 1           True        False           True           False            False
# 2           True        False           True           False            False
# 3           True        False           True           False             True
# 4           True        False           True           False            False
# ...          ...          ...            ...             ...              ...
# 7027       False         True          False            True            False
# 7028       False         True          False            True            False
# 7029       False         True          False            True             True
# 7030       False         True           True           False            False
# 7031        True        False           True           False            False
#
#       ...  PaymentMethod_Bank transfer (automatic)  \
# 0     ...                                    False
# 1     ...                                    False
# 2     ...                                    False
# 3     ...                                     True
# 4     ...                                    False
# ...   ...                                      ...
# 7027  ...                                    False
# 7028  ...                                    False
# 7029  ...                                    False
# 7030  ...                                    False
# 7031  ...                                     True
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                     False                            True
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                            True
# ...                                     ...                             ...
# 7027                                  False                           False
# 7028                                   True                           False
# 7029                                  False                            True
# 7030                                  False                           False
# 7031                                  False                           False
#
#       PaymentMethod_Mailed check  tenure_group_1 - 12  tenure_group_13 - 24  \
# 0                          False                 True                 False
# 1                           True                False                 False
# 2                           True                 True                 False
# 3                          False                False                 False
# 4                          False                 True                 False
# ...                          ...                  ...                   ...
# 7027                        True                False                  True
# 7028                       False                False                 False
# 7029                       False                 True                 False
# 7030                        True                 True                 False
# 7031                       False                False                 False
#
#       tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 0                    False                 False                 False
# 1                     True                 False                 False
# 2                    False                 False                 False
# 3                    False                  True                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 7027                 False                 False                 False
# 7028                 False                 False                 False
# 7029                 False                 False                 False
# 7030                 False                 False                 False
# 7031                 False                 False                 False
#
#       tenure_group_61 - 72
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 7027                 False
# 7028                  True
# 7029                 False
# 7030                 False
# 7031                  True
#
# [7032 rows x 50 columns]

# %%
y=df['Churn']
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %% [markdown]
# ##### Train Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf=RandomForestClassifier(n_estimators=100, random_state = 100,max_depth=6, min_samples_leaf=8)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=100)

# %%
y_pred=model_rf.predict(x_test)

# %%
model_rf.score(x_test,y_test)
# Out:
# 0.7981520966595593

# %%
print(classification_report(y_test, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1043
#            1       0.65      0.48      0.55       364
#
#     accuracy                           0.80      1407
#    macro avg       0.74      0.69      0.71      1407
# weighted avg       0.79      0.80      0.79      1407

# %%
sm = SMOTEENN()
X_resampled1, y_resampled1 = sm.fit_resample(x,y)

# %%
xr_train1,xr_test1,yr_train1,yr_test1=train_test_split(X_resampled1, y_resampled1,test_size=0.2)

# %%
model_rf_smote=RandomForestClassifier(n_estimators=100, criterion='gini', random_state = 42,max_depth=6, min_samples_leaf=8)

# %%
model_rf_smote.fit(xr_train1,yr_train1)
# Out:
# RandomForestClassifier(max_depth=6, min_samples_leaf=8, random_state=42)

# %%
yr_predict1 = model_rf_smote.predict(xr_test1)

# %%
model_score_r1 = model_rf_smote.score(xr_test1, yr_test1)

# %%
print(model_score_r1)
print(metrics.classification_report(yr_test1, yr_predict1))
# Out:
# 0.9369676320272572
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       534
#            1       0.93      0.96      0.94       640
#
#     accuracy                           0.94      1174
#    macro avg       0.94      0.93      0.94      1174
# weighted avg       0.94      0.94      0.94      1174

# %%
print(metrics.confusion_matrix(yr_test1, yr_predict1))
# Out:
# [[486  48]
#  [ 26 614]]

# %% [markdown]
# #### Pickling the model

# %%
import pickle

# %%
filename = 'new.pkl'

# %%
pickle.dump(model_rf_smote, open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

# %%
model_score_r1 = load_model.score(xr_test1, yr_test1)

# %%
model_score_r1
# Out:
# 0.9369676320272572

# %% [markdown]
# ##### Our final model i.e. RF Classifier with SMOTEENN, is now ready and dumped in model.sav, which we will use and prepare API's so that we can access our model from UI.

# %%
x_test
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 1947              0           95.50       1916.20           True        False
# 5974              0           50.35       1098.85           True        False
# 818               0          106.35       6751.35           True        False
# 5706              0          108.15       3432.90          False         True
# 5970              0           19.65        978.00          False         True
# ...             ...             ...           ...            ...          ...
# 3854              0          105.45       2715.30           True        False
# 6683              0           48.25       1293.80           True        False
# 4446              0           19.40         93.40          False         True
# 2101              0           59.45       3157.00          False         True
# 2372              0           55.30       2654.05          False         True
#
#       Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# 1947       False         True          False            True            False
# 5974        True        False           True           False             True
# 818        False         True           True           False            False
# 5706        True        False           True           False            False
# 5970        True        False           True           False            False
# ...          ...          ...            ...             ...              ...
# 3854        True        False          False            True            False
# 6683        True        False           True           False             True
# 4446        True        False           True           False            False
# 2101       False         True          False            True            False
# 2372        True        False          False            True            False
#
#       ...  PaymentMethod_Bank transfer (automatic)  \
# 1947  ...                                     True
# 5974  ...                                    False
# 818   ...                                    False
# 5706  ...                                    False
# 5970  ...                                     True
# ...   ...                                      ...
# 3854  ...                                    False
# 6683  ...                                    False
# 4446  ...                                    False
# 2101  ...                                    False
# 2372  ...                                    False
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 1947                                  False                           False
# 5974                                  False                            True
# 818                                   False                            True
# 5706                                   True                           False
# 5970                                  False                           False
# ...                                     ...                             ...
# 3854                                  False                            True
# 6683                                  False                            True
# 4446                                  False                           False
# 2101                                   True                           False
# 2372                                  False                            True
#
#       PaymentMethod_Mailed check  tenure_group_1 - 12  tenure_group_13 - 24  \
# 1947                       False                False                  True
# 5974                       False                False                  True
# 818                        False                False                 False
# 5706                       False                False                 False
# 5970                       False                False                 False
# ...                          ...                  ...                   ...
# 3854                       False                False                 False
# 6683                       False                False                 False
# 4446                        True                 True                 False
# 2101                       False                False                 False
# 2372                       False                False                 False
#
#       tenure_group_25 - 36  tenure_group_37 - 48  tenure_group_49 - 60  \
# 1947                 False                 False                 False
# 5974                 False                 False                 False
# 818                  False                 False                 False
# 5706                  True                 False                 False
# 5970                 False                 False                  True
# ...                    ...                   ...                   ...
# 3854                  True                 False                 False
# 6683                  True                 False                 False
# 4446                 False                 False                 False
# 2101                 False                 False                  True
# 2372                 False                  True                 False
#
#       tenure_group_61 - 72
# 1947                 False
# 5974                 False
# 818                   True
# 5706                 False
# 5970                 False
# ...                    ...
# 3854                 False
# 6683                 False
# 4446                 False
# 2101                 False
# 2372                 False
#
# [1407 rows x 50 columns]

# %%
yr_predict1
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(xr_train1,yr_train1)

#Predict the response for test dataset
yr_pred = clf.predict(xr_test1)

# %%
New_model_score_r1 = clf.score(xr_test1, yr_test1)

# %%
print(New_model_score_r1)
print(metrics.classification_report(yr_test1, yr_pred))
# Out:
# 0.9378194207836457
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       534
#            1       0.95      0.93      0.94       640
#
#     accuracy                           0.94      1174
#    macro avg       0.94      0.94      0.94      1174
# weighted avg       0.94      0.94      0.94      1174

# %%
y = clf.prdict(xr_test1[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-31d3e1f320a1> in <cell line: 1>()
# ----> 1 y = clf.prdict(xr_test1[1])
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'prdict'
